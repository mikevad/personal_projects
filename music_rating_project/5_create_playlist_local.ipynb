# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

pd.set_option('display.max_columns', 500)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
s3_location = 's3://djk-ml-sagemaker/music_lyrics/'

# %%
xgb_model = pickle.load(open('xgb_model.sav', 'rb'))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.21.3 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.21.3 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator VarianceThreshold from version 0.21.3 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.21.3 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator Pipeline from version 0.21.3 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
eligible_songs = pd.read_csv('eligible_song_pool.csv')

# %%
eligible_songs.head()
# Out:
#                                               lyrics       song_title  \
# 0  \n\n[Verse 1]\nI can't remember\nThe words wer...   If You Want It
# 1  \n\n[Verse 1]\nI'm not that kind of fool\nWho ...        Superbike
# 2  \n\n[Verse 1]\nPoint me to my chair\nMake me s...        Peace Out
# 3  \n\n[Verse 1]\nUsed to be the one to cry\nAnd ...         Devotion
# 4  \n\n[Verse 1]\nI'm sinking in my bed\nWe’re le...  Nighttime Drive
#
#   artist_name  liked                                     cleaned_lyrics
# 0     Jay Som    NaN  remember word form mouth have find bring joy p...
# 1     Jay Som    NaN  kind fool need read room somebody tell fall li...
# 2     Jay Som    NaN  point chair sing awful song bear go hard hard ...
# 3     Jay Som    NaN  cry feel emotion need path find strange devoti...
# 4     Jay Som    NaN  sink bed be leave town tomorrow memory feel nu...

# %%
predictions = xgb_model.predict_proba(eligible_songs['cleaned_lyrics'])

# %%
preds = xgb_model.predict(eligible_songs['cleaned_lyrics'])

# %%
predictions[:5]
preds[:5]
# Out:
# array([[0.51532006, 0.4846799 ],
#        [0.4579932 , 0.5420068 ],
#        [0.61323786, 0.38676214],
#        [0.45571375, 0.54428625],
#        [0.5001302 , 0.49986985]], dtype=float32)
# array([0., 1., 0., 1., 0.])

# %%
eligible_songs['recommendation'] = [probas[1] for probas in predictions]

# %%
eligible_songs.head()
# Out:
#                                               lyrics       song_title  \
# 0  \n\n[Verse 1]\nI can't remember\nThe words wer...   If You Want It
# 1  \n\n[Verse 1]\nI'm not that kind of fool\nWho ...        Superbike
# 2  \n\n[Verse 1]\nPoint me to my chair\nMake me s...        Peace Out
# 3  \n\n[Verse 1]\nUsed to be the one to cry\nAnd ...         Devotion
# 4  \n\n[Verse 1]\nI'm sinking in my bed\nWe’re le...  Nighttime Drive
#
#   artist_name  liked                                     cleaned_lyrics  \
# 0     Jay Som    NaN  remember word form mouth have find bring joy p...
# 1     Jay Som    NaN  kind fool need read room somebody tell fall li...
# 2     Jay Som    NaN  point chair sing awful song bear go hard hard ...
# 3     Jay Som    NaN  cry feel emotion need path find strange devoti...
# 4     Jay Som    NaN  sink bed be leave town tomorrow memory feel nu...
#
#    recommendation
# 0        0.484680
# 1        0.542007
# 2        0.386762
# 3        0.544286
# 4        0.499870

# %%
all_music = pd.read_csv(f'{s3_location}all_music.csv')

# %%
all_music.head()
# Out:
#                                     Name         Artist  \
# 0                                  Bunny        Tourist
# 1                                   1990          PINES
# 2  Scarlett Groove (feat. Saint Saviour)  Maribou State
# 3                         If You Want It        Jay Som
# 4                              Superbike        Jay Som
#
#                          Composer                 Album Grouping Work  \
# 0                William Phillips        Bunny - Single      NaN  NaN
# 1  Adam Dormand & James Kenneally         1990 - Single      NaN  NaN
# 2   Maribou State & Saint Saviour  Scarlett Groove - EP      NaN  NaN
# 3                             NaN               Anak Ko      NaN  NaN
# 4                             NaN               Anak Ko      NaN  NaN
#
#    Movement Number  Movement Count  Movement Name        Genre     Size  \
# 0              NaN             NaN            NaN  Electronica  7738301
# 1              NaN             NaN            NaN   Electronic  6603206
# 2              NaN             NaN            NaN   Electronic  9867297
# 3              NaN             NaN            NaN          NaN  7745797
# 4              NaN             NaN            NaN          NaN  9366424
#
#     Time  Disc Number  Disc Count  Track Number  Track Count    Year  \
# 0  214.0          1.0         1.0           1.0          1.0  2019.0
# 1  183.0          1.0         1.0           1.0          1.0  2019.0
# 2  282.0          1.0         1.0           1.0          4.0  2012.0
# 3  193.0          NaN         NaN           1.0          NaN  2019.0
# 4  233.0          NaN         NaN           2.0          NaN  2019.0
#
#        Date Modified         Date Added  Bit Rate  Sample Rate  \
# 0    9/5/19, 5:49 PM    9/5/19, 5:49 PM       256      44100.0
# 1   9/4/19, 11:11 AM   9/4/19, 11:11 AM       256      44100.0
# 2  8/27/19, 10:39 AM  8/27/19, 10:39 AM       256      44100.0
# 3   8/24/19, 3:39 AM   8/24/19, 3:28 AM       320      44100.0
# 4   8/24/19, 3:39 AM   8/24/19, 3:28 AM       320      44100.0
#
#    Volume Adjustment                        Kind  Equalizer    Comments  \
# 0                NaN  Apple Music AAC audio file        NaN         NaN
# 1                NaN  Apple Music AAC audio file        NaN         NaN
# 2                NaN  Apple Music AAC audio file        NaN         NaN
# 3                NaN             MPEG audio file        NaN  plixid.com
# 4                NaN             MPEG audio file        NaN  plixid.com
#
#    Plays      Last Played  Skips Last Skipped  My Rating  \
# 0    NaN              NaN    NaN          NaN        NaN
# 1    3.0  9/4/19, 7:34 PM    NaN          NaN        NaN
# 2    4.0  9/3/19, 8:07 PM    NaN          NaN        NaN
# 3    3.0  9/3/19, 8:11 PM    NaN          NaN        NaN
# 4    3.0  9/3/19, 8:14 PM    NaN          NaN        NaN
#
#                                             Location
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The Library/Music/Music/Jay Som/Anak Ko/01 If ...
# 4  The Library/Music/Music/Jay Som/Anak Ko/02 Sup...

# %%
playlist_df = pd.merge(all_music, eligible_songs, how = 'inner', left_on = ['Artist', 'Name'], right_on = ['artist_name', 'song_title'])

# %%
playlist_df.shape
# Out:
# (40997, 37)

# %%
playlist_df = playlist_df[playlist_df['recommendation'].notnull()]

# %%
playlist_df.head()
# Out:
#               Name   Artist Composer    Album Grouping Work  Movement Number  \
# 0   If You Want It  Jay Som      NaN  Anak Ko      NaN  NaN              NaN
# 1        Superbike  Jay Som      NaN  Anak Ko      NaN  NaN              NaN
# 2        Peace Out  Jay Som      NaN  Anak Ko      NaN  NaN              NaN
# 3         Devotion  Jay Som      NaN  Anak Ko      NaN  NaN              NaN
# 4  Nighttime Drive  Jay Som      NaN  Anak Ko      NaN  NaN              NaN
#
#    Movement Count  Movement Name Genre      Size   Time  Disc Number  \
# 0             NaN            NaN   NaN   7745797  193.0          NaN
# 1             NaN            NaN   NaN   9366424  233.0          NaN
# 2             NaN            NaN   NaN  10301608  257.0          NaN
# 3             NaN            NaN   NaN   8511696  212.0          NaN
# 4             NaN            NaN   NaN   7779236  193.0          NaN
#
#    Disc Count  Track Number  Track Count    Year     Date Modified  \
# 0         NaN           1.0          NaN  2019.0  8/24/19, 3:39 AM
# 1         NaN           2.0          NaN  2019.0  8/24/19, 3:39 AM
# 2         NaN           3.0          NaN  2019.0  8/24/19, 3:39 AM
# 3         NaN           4.0          NaN  2019.0  8/24/19, 3:39 AM
# 4         NaN           5.0          NaN  2019.0  8/24/19, 3:39 AM
#
#          Date Added  Bit Rate  Sample Rate  Volume Adjustment  \
# 0  8/24/19, 3:28 AM       320      44100.0                NaN
# 1  8/24/19, 3:28 AM       320      44100.0                NaN
# 2  8/24/19, 3:28 AM       320      44100.0                NaN
# 3  8/24/19, 3:28 AM       320      44100.0                NaN
# 4  8/24/19, 3:28 AM       320      44100.0                NaN
#
#               Kind  Equalizer    Comments  Plays      Last Played  Skips  \
# 0  MPEG audio file        NaN  plixid.com    3.0  9/3/19, 8:11 PM    NaN
# 1  MPEG audio file        NaN  plixid.com    3.0  9/3/19, 8:14 PM    NaN
# 2  MPEG audio file        NaN  plixid.com    3.0  9/3/19, 8:19 PM    NaN
# 3  MPEG audio file        NaN  plixid.com    3.0  9/3/19, 8:22 PM    NaN
# 4  MPEG audio file        NaN  plixid.com    4.0  9/3/19, 8:25 PM    NaN
#
#   Last Skipped  My Rating                                           Location  \
# 0          NaN        NaN  The Library/Music/Music/Jay Som/Anak Ko/01 If ...
# 1          NaN        NaN  The Library/Music/Music/Jay Som/Anak Ko/02 Sup...
# 2          NaN        NaN  The Library/Music/Music/Jay Som/Anak Ko/03 Pea...
# 3          NaN        NaN  The Library/Music/Music/Jay Som/Anak Ko/04 Dev...
# 4          NaN        NaN  The Library/Music/Music/Jay Som/Anak Ko/05 Nig...
#
#                                               lyrics       song_title  \
# 0  \n\n[Verse 1]\nI can't remember\nThe words wer...   If You Want It
# 1  \n\n[Verse 1]\nI'm not that kind of fool\nWho ...        Superbike
# 2  \n\n[Verse 1]\nPoint me to my chair\nMake me s...        Peace Out
# 3  \n\n[Verse 1]\nUsed to be the one to cry\nAnd ...         Devotion
# 4  \n\n[Verse 1]\nI'm sinking in my bed\nWe’re le...  Nighttime Drive
#
#   artist_name  liked                                     cleaned_lyrics  \
# 0     Jay Som    NaN  remember word form mouth have find bring joy p...
# 1     Jay Som    NaN  kind fool need read room somebody tell fall li...
# 2     Jay Som    NaN  point chair sing awful song bear go hard hard ...
# 3     Jay Som    NaN  cry feel emotion need path find strange devoti...
# 4     Jay Som    NaN  sink bed be leave town tomorrow memory feel nu...
#
#    recommendation
# 0        0.484680
# 1        0.542007
# 2        0.386762
# 3        0.544286
# 4        0.499870

# %%
playlist_df = playlist_df.drop(columns = ['lyrics', 'song_title', 'artist_name', 'liked', 'cleaned_lyrics'])

# %%
playlist_df['name_lower'] = [s.lower() for s in playlist_df['Name']]
playlist_df['Artist_lower'] = [s.lower() for s in playlist_df['Artist']]

# %%
playlist_df = playlist_df.drop_duplicates(subset = ['name_lower', 'Artist_lower'])

# %%
playlist_df.recommendation.value_counts(bins = 20).sort_index(ascending = False)
# Out:
# (0.67, 0.69]        12
# (0.649, 0.67]       67
# (0.628, 0.649]     108
# (0.608, 0.628]     240
# (0.587, 0.608]     716
# (0.567, 0.587]    3867
# (0.546, 0.567]    2736
# (0.526, 0.546]    3546
# (0.505, 0.526]    4394
# (0.484, 0.505]    4983
# (0.464, 0.484]    4847
# (0.443, 0.464]    4105
# (0.423, 0.443]    2851
# (0.402, 0.423]    1932
# (0.381, 0.402]    1106
# (0.361, 0.381]     640
# (0.34, 0.361]      320
# (0.32, 0.34]       158
# (0.299, 0.32]       58
# (0.277, 0.299]      20
# Name: recommendation, dtype: int64

# %%
playlist_df = playlist_df.drop(columns = ['name_lower', 'Artist_lower'])

# %%
export_df = playlist_df.sort_values(by = 'recommendation', ascending = False).iloc[:100]

# %%
export_df.columns
# Out:
# Index(['Name', 'Artist', 'Composer', 'Album', 'Grouping', 'Work',
#        'Movement Number', 'Movement Count', 'Movement Name', 'Genre', 'Size',
#        'Time', 'Disc Number', 'Disc Count', 'Track Number', 'Track Count',
#        'Year', 'Date Modified', 'Date Added', 'Bit Rate', 'Sample Rate',
#        'Volume Adjustment', 'Kind', 'Equalizer', 'Comments', 'Plays',
#        'Last Played', 'Skips', 'Last Skipped', 'My Rating', 'Location',
#        'recommendation'],
#       dtype='object')

# %%
export_df[['Name', 'Artist', 'recommendation']].head(20)
# Out:
#                               Name            Artist  recommendation
# 13489               Is It Worth It    Chase & Status        0.690204
# 13003                 I Don't Know        Plastikman        0.687797
# 33841         What Do You Wanna Be          Dispatch        0.681355
# 22307            Through the Walls              RJD2        0.677297
# 23760                     16 Years        Phantogram        0.677272
# 14614       Cape Cod Kwassa Kwassa   Vampire Weekend        0.676840
# 31125                 Roseablility          Idlewild        0.676242
# 12756                    Floorplan    Tegan And Sara        0.675556
# 10461      Always (Route 94 Remix)                MK        0.674566
# 24998         World's End Rhapsody           Nujabes        0.671324
# 17955                Vein of Stars  The Flaming Lips        0.670481
# 24366                        Drone        Panda Bear        0.669721
# 21868                    Sanctuary            SBTRKT        0.669257
# 12496  This Is What It Feels Like   Armin Van Buuren        0.668990
# 22196               Endless Shovel        Rogue Wave        0.666670
# 39015      Heads Up [2011 Version]        Bassnectar        0.665625
# 24758   Touched Something's Hollow       Of Montreal        0.665310
# 10611                       Mumbai             oOoOO        0.665127
# 13276                      With Me             Pryda        0.664692
# 22933                       Lurgee         Radiohead        0.664659

# %%
apple_music_playlist = export_df[['Name', 'Artist', 'Composer', 'Album', 'Grouping', 'Work',
       'Movement Number', 'Movement Count', 'Movement Name', 'Genre', 'Size',
       'Time', 'Disc Number', 'Disc Count', 'Track Number', 'Track Count',
       'Year', 'Date Modified', 'Date Added', 'Bit Rate', 'Sample Rate',
       'Volume Adjustment', 'Kind', 'Equalizer', 'Comments', 'Plays',
       'Last Played', 'Skips', 'Last Skipped', 'My Rating', 'Location']].copy()

# %%
with open('recommedations_v0_3','w') as write_tsv:
    write_tsv.write(apple_music_playlist.to_csv(sep='\t', index=False))
# Out:
# 26575
